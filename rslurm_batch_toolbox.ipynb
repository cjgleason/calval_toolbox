# %%
library(rslurm, lib.loc = "/nas/cee-water/cjgleason/r-lib/",quietly = TRUE)
library(whisker, lib.loc = "/nas/cee-water/cjgleason/r-lib/",quietly = TRUE)

reprocess_switch=1 #0 or 1. 1 means to recreate all reach and node products following some change in processing. 
#0 means to just append to existing dataframes
process_PTs=1 # switch. do you want to deal with PTs and all downstream processing?
process_airborne =0 #swtich

# hubname='UNC'
# rivername='WK'
# continent='oc'
# PT_key_file= 'SWOTCalVal_WK_KEY_20230331_20230507_1.csv' #WK
# utm_zone='58 +south'#WK='58 +south'

# hubname='UNC'
# rivername='PY'
# continent='na'
# utm_zone=6 

# hubname='UNC'
# rivername='YR'
# continent='na'
# utm_zone=6 

# hubname='UMass'
# rivername='CR'
# continent='na'
# PT_key_file=c('SWOTCalVal_CR_Key_20230322_20230614.csv',
#               'SWOTCalVal_CR_Key_20230516_20230613.csv') #CT
# utm_zone=18 #Ct= 18

# hubname='CU'
# rivername='WM'
# continent='na'
# PT_key_file= c('SWOTCalVal_WM_KEY_20230326_20230510.csv',
#                'SWOTCalVal_WM_KEY_20230509_20230601.csv')#WM
# utm_zone=10 #WM= 10

hubname='Brown'
rivername='NS'
continent='na'
PT_key_file= 'SWOTCalVal_NS_KEY_20230525_20230613.csv' #WM
utm_zone=13 #NS= 13


reach_end_buffer=500 #m, 'extends' the reach

#PT offset controls-----

dist_thresh_offset=150 # 150m
time_thresh_offset= 15*60 #minutes as seconds, centered, so 15 =30 mins total time
GNSS_sd_thresh=0.15 # 15cm how much variance do you want in the GNSS data when it is within the distance threshold?
offset_sd_thresh=0.10 #m, so 10cm. the the PT apparantly shift by more than a cm?
change_thresh_15_min=0.10#m- does it change more than 5cm in 15 minutes? that is a discontinuity in offset

# 'set' errors added to PT products
alongstream_error= 0.0001*200 #m error we get from the downstream slope of a reach in a node. This placeholder is a 1e-4 slope over a 200m node
crossstream_error= 0.005 #m error we get from PT not representing cross stream superelevation/noise in a node
measurement_error= 0.001 #m error we get from PT measurement itself 

#matching controls
time_threshold_sec_match= 120*60 #two hour
wse_threshold_m_match=0.05 #within 5cm
distance_threshold_m_match =200 #within 200m

source('/nas/cee-water/cjgleason/calval_toolbox/toolbox_main_batch.R')

# %%
source('/nas/cee-water/cjgleason/calval_toolbox/toolbox_main_batch.R')
test=toolbox_main_batch(hubname,
                            rivername=rivername,
                            continent=continent,
                            PT_key_file=PT_key_file,
                            utm_zone=utm_zone,
                            reach_end_buffer=reach_end_buffer,
                           reprocess_switch=reprocess_switch,
                           process_PTs=process_PTs,
                           process_airborne=process_airborne,
                           dist_thresh_offset=dist_thresh_offset,
                           time_thresh_offset=time_thresh_offset,
                           GNSS_sd_thresh=GNSS_sd_thresh,
                           offset_sd_thresh=offset_sd_thresh,
                           change_thresh_15_min=change_thresh_15_min,
                           alongstream_error=alongstream_error,
                           crossstream_error=crossstream_error,
                           measurement_error=measurement_error, 
                            time_threshold_sec_match=time_threshold_sec_match,
                            wse_threshold_m_match=wse_threshold_m_match,
                            distance_threshold_m_match=distance_threshold_m_match)
# Out:
# Attaching package: ‘dplyr’
#
#
# The following objects are masked from ‘package:stats’:
#
#     filter, lag
#
#
# The following objects are masked from ‘package:base’:
#
#     intersect, setdiff, setequal, union
# [1
SWOTCalVal_WK_GNSS_L0_Rec12_20230507T023755_20230507T033759
# 6 SWOTCalVal_WK_GNSS_L0_Rec12_20230507T023755_20230507T033759
#              datetime                                     keyid
# 1 2023-04-06 03:30:00 SWOTCalVal_WK_KEY_20230331_20230507_1.csv
# 2 2023-04-06 03:45:00 SWOTCalVal_WK_KEY_20230331_20230507_1.csv
# 3 2023-04-06 04:00:00 SWOTCalVal_WK_KEY_20230331_20230507_1.csv
# 4 2023-04-06 04:15:00 SWOTCalVal_WK_KEY_20230331_20230507_1.csv
# 5 2023-04-06 04:30:00 SWOTCalVal_WK_KEY_20230331_20230507_1.csv
# 6 2023-04-06 04:45:00 SWOTCalVal_WK_KEY_20230331_20230507_1.csv
#   Date_GNSS_Install Date_GNSS_Uninstall
# 1        04/06/2023          05/07/2023
# 2        04/06/2023          05/07/2023
# 3        04/06/2023          05/07/2023
# 4        04/06/2023          05/07/2023
# 5        04/06/2023          05/07/2023
# 6        04/06/2023          05/07/2023
# [1] "20230406T035520_20230406T045700"
# [1] "20230507T023755_20230507T033759"
# object has no named columns; assuming order is lon then lat
#
# object has no named columns; assuming order is lon then lat
# [1] "SWOTCalVal_WK_PT_L1_PT213_20230330T110000_20230507T024500_20230705T153938_SWOTCalVal_WK_KEY_20230331_20230507_1.csv"
# [1] "this file passed all checks"
# [1] "/nas/cee-water/cjgleason/calval/xml_scripts/UNC/Munged/Munged__20230705/SWOTCalVal_WK_PT_L1_PT217_20230405T002300_20230430T021500_20230705T153938.csv"
#           pt_time_UTC    pt_lat   pt_lon      pt_install_UTC
# 1 2023-04-08 04:45:00 -43.44671 172.5045 2023-04-08 04:42:00
# 2 2023-04-08 05:00:00 -43.44671 172.5045 2023-04-08 04:42:00
# 3 2023-04-08 05:15:00 -43.44671 172.5045 2023-04-08 04:42:00
# 4 2023-04-08 05:30:00 -43.44671 172.5045 2023-04-08 04:42:00
# 5 2023-04-08 05:45:00 -43.44671 172.5045 2023-04-08 04:42:00
# 6 2023-04-08 06:00:00 -43.44671 172.5045 2023-04-08 04:42:00
#      pt_uninstall_UTC    gnss_install_UTC  gnss_uninstall_UTC
# 1 2023-04-30 01:31:00 2023-04-30 00:11:00 2023-04-30 01:11:00
# 2 2023-04-30 01:31:00 2023-04-30 00:11:00 2023-04-30 01:11:00
# 3 2023-04-30 01:31:00 2023-04-30 00:11:00 2023-04-30 01:11:00
# 4 2023-04-30 01:31:00 2023-04-30 00:11:00 2023-04-30 01:11:00
# 5 2023-04-30 01:31:00 2023-04-30 00:11:00 2023-04-30 01:11:00
# 6 2023-04-30 01:31:00 2023-04-30 00:11:00 2023-04-30 01:11:00
#       install_method pt_serial pt_level temperature
# 1 Metal pipe on rock   2153097    1.247        13.4
# 2 Metal pipe on rock   2153097    1.233        12.9
# 3 Metal pipe on rock   2153097    1.229        12.9
# 4 Metal pipe on rock   2153097    1.241        12.8
# 5 Metal pipe on rock   2153097    1.229        12.7
# 6 Metal pipe on rock   2153097    1.238        12.7
#                                              driftID_install
# 1 SWOTCalVal_WK_GNSS_L0_Rec5_20230430T001139_20230430T011142
# 2 SWOTCalVal_WK_GNSS_L0_Rec5_20230430T001139_20230430T011142
# 3 SWOTCalVal_WK_GNSS_L0_Rec5_20230430T001139_20230430T011142
# 4 SWOTCalVal_WK_GNSS_L0_Rec5_20230430T001139_20230430T011142
# 5 SWOTCalVal_WK_GNSS_L0_Rec5_20230430T001139_20230430T011142
# 6 SWOTCalVal_WK_GNSS_L0_Rec5_20230430T001139_20230430T011142
#                                            driftID_uninstall
# 1 SWOTCalVal_WK_GNSS_L0_Rec5_20230430T001139_20230430T011142
# 2 SWOTCalVal_WK_GNSS_L0_Rec5_20230430T001139_20230430T011142
# 3 SWOTCalVal_WK_GNSS_L0_Rec5_20230430T001139_20230430T011142
# 4 SWOTCalVal_WK_GNSS_L0_Rec5_20230430T001139_20230430T011142
# 5 SWOTCalVal_WK_GNSS_L0_Rec5_20230430T001139_20230430T011142
# 6 SWOTCalVal_WK_GNSS_L0_Rec5_20230430T001139_20230430T011142
#              datetime                                     keyid
# 1 2023-04-08 04:45:00 SWOTCalVal_WK_KEY_20230331_20230507_1.csv
# 2 2023-04-08 05:00:00 SWOTCalVal_WK_KEY_20230331_20230507_1.csv
# 3 2023-04-08 05:15:00 SWOTCalVal_WK_KEY_20230331_20230507_1.csv
# 4 2023-04-08 05:30:00 SWOTCalVal_WK_KEY_20230331_20230507_1.csv
# 5 2023-04-08 05:45:00 SWOTCalVal_WK_KEY_20230331_20230507_1.csv
# 6 2023-04-08 06:00:00 SWOTCalVal_WK_KEY_20230331_20230507_1.csv
#   Date_GNSS_Install Date_GNSS_Uninstall
# 1         4/30/2023           4/30/2023
# 2         4/30/2023           4/30/2023
# 3         4/30/2023           4/30/2023
# 4         4/30/2023           4/30/2023
# 5         4/30/2023           4/30/2023
# 6         4/30/2023           4/30/2023
# [1] "20230430T001139_20230430T011142"
# [1] "20230430T001139_20230430T011142"
# object has no named columns; assuming order is lon then lat
#
# object has no named columns; assuming order is lon then lat
# [1] "SWOTCalVal_WK_PT_L1_PT217_20230405T002300_20230430T021500_20230705T153938_SWOTCalVal_WK_KEY_20230331_20230507_1.csv"
# [1] "this file passed all checks"
# [1] "ending PT processing"
# [1] "starting drift dataframe creation"
# Linking to GEOS 3.11.1, GDAL 3.6.2, PROJ 9.1.0; sf_use_s2() is TRUE
#
# Loading required package: sp
#
# Please note that rgdal will be retired by the end of 2023,
# plan transition to sf/stars/terra functions using GDAL and PROJ
# at your earliest convenience.
#
# rgdal: version: 1.5-32, (SVN revision 1176)
# Geospatial Data Abstraction Library extensions to R successfully loaded
# Loaded GDAL runtime: GDAL 3.6.2, released 2023/01/02
# Path to GDAL shared files: /home/cjgleason_umass_edu/.conda/envs/supposedlybetter/share/gdal
#  GDAL does not use iconv for recoding strings.
# GDAL binary built with GEOS: TRUE
# Loaded PROJ runtime: Rel. 9.1.0, September 1st, 2022, [PJ_VERSION: 910]
# Path to PROJ shared files: /home/cjgleason_umass_edu/.local/share/proj:/home/cjgleason_umass_edu/.conda/envs/supposedlybetter/share/proj
# PROJ CDN enabled: TRUE
# Linking to sp version:1.5-1
# To mute warnings of possible GDAL/OSR exportToProj4() degradation,
# use options("rgdal_show_exportToProj4_warnings"="none") before loading sp or rgdal.
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] "/nas/cee-water/cjgleason/calval/Processed data/UNC/Data frames/reprocessed_2023_08_30/node/WK_drift_node_wses.csv"
# [1] "/nas/cee-water/cjgleason/calval/Processed data/UNC/Data frames/reprocessed_2023_08_30//reach/WK_drift_reach_wse_slope.csv"
# [1] "ending drift dataframe creation"
# [1] "starting pt dataframe creation"
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] ">>>> WARNING <<<  attribute _FillValue is an 8-byte value, but R"
# [1] "does not support this data type. I am returning a double precision"
# [1] "floating point, but you must be aware that this could lose precision!"
# [1] "ending pt dataframe creation"
# [1] "starting matching"
# [1] "ending matching"

# %%
#slurm block
slurm_options= list(mem=128000,partition ='ceewater_cjgleason-cpu', 'time'='50:00:00', 
                    error='slurm.%N.%j.err', 'mail-type'= 'END', 'mail-user'='cjgleason@umass.edu')#,
                 #  export = 'TMPDIR=/tmp'  )

sjob <- slurm_map( list(hubname),toolbox_main_batch,
                               rivername=rivername,
                            continent=continent,
                            PT_key_file=PT_key_file,
                            utm_zone=utm_zone,
                            reach_end_buffer=reach_end_buffer,
                           reprocess_switch=reprocess_switch,
                           process_PTs=process_PTs,
                           process_airborne=process_airborne,
                           dist_thresh_offset=dist_thresh_offset,
                           time_thresh_offset=time_thresh_offset,
                           GNSS_sd_thresh=GNSS_sd_thresh,
                           offset_sd_thresh=offset_sd_thresh,
                           change_thresh_15_min=change_thresh_15_min,
                           alongstream_error=alongstream_error,
                           crossstream_error=crossstream_error,
                           measurement_error=measurement_error, 
                            time_threshold_sec_match=time_threshold_sec_match,
                            wse_threshold_m_match=wse_threshold_m_match,
                            distance_threshold_m_match=distance_threshold_m_match,
                  jobname = hubname,
                  nodes = 1, preschedule_cores=FALSE,
                  cpus_per_node = 48, submit = TRUE, slurm_options=slurm_options,libPaths="/nas/cee-water/cjgleason/r-lib/" )
# Out:
# Submitted batch job 9734464
