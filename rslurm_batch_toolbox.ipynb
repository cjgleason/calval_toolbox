# %%
reprocess_switch=0 #0 or 1. 1 means to recreate all reach and node products following some change in processing. 
#0 means to just append to existing dataframes
process_PTs=1 # switch. do you want to deal with PTs and all downstream processing?
process_airborne =0 #swtich

# hubname='UNC'
# rivername='WK'
# continent='oc'
# PT_key_file= 'SWOTCalVal_WK_KEY_20230331_20230507_1.csv' #WK
# utm_zone='58 +south'#WK='58 +south'

# hubname='UNC'
# rivername='PY'
# continent='na'
# utm_zone=6 

# hubname='UNC'
# rivername='YR'
# continent='na'
# utm_zone=6 

# hubname='UMass'
# rivername='CR'
# continent='na'
# PT_key_file=c('SWOTCalVal_CR_Key_20230322_20230614.csv',
#               'SWOTCalVal_CR_Key_20230516_20230613.csv') #CT
# utm_zone=18 #Ct= 18

# hubname='CU'
# rivername='WM'
# continent='na'
# PT_key_file= c('SWOTCalVal_WM_KEY_20230326_20230510.csv',
#                'SWOTCalVal_WM_KEY_20230509_20230601.csv')#WM
# utm_zone=10 #WM= 10

hubname='Brown'
rivername='NS'
continent='na'
PT_key_file= 'SWOTCalVal_NS_KEY_20230525_20230613.csv' #WM
utm_zone=13 #NS= 13


reach_end_buffer=500 #m, 'extends' the reach

#PT offset controls-----

dist_thresh_offset=150 # 150m
time_thresh_offset= 15*60 #minutes as seconds, centered, so 15 =30 mins total time
GNSS_sd_thresh=0.15 # 15cm how much variance do you want in the GNSS data when it is within the distance threshold?
offset_sd_thresh=0.10 #m, so 10cm. the the PT apparantly shift by more than a cm?
change_thresh_15_min=0.05#m- does it change more than 5cm in 15 minutes? that is a discontinuity in offset

# 'set' errors added to PT products
alongstream_error= 0.0001*200 #m error we get from the downstream slope of a reach in a node. This placeholder is a 1e-4 slope over a 200m node
crossstream_error= 0.005 #m error we get from PT not representing cross stream superelevation/noise in a node
measurement_error= 0.001 #m error we get from PT measurement itself 

#matching controls
time_threshold_sec_match= 120*60 #two hour
wse_threshold_m_match=0.05 #within 5cm
distance_threshold_m_match =200 #within 200m

# %%
source('/nas/cee-water/cjgleason/calval_toolbox/toolbox_main_batch.R')
toolbox_main_batch=toolbox_main_batch(hubname=hubname,
                            rivername=rivername,
                            continent=continent,
                            PT_key_file=PT_key_file,
                            utm_zone=utm_zone,
                            reach_end_buffer=reach_end_buffer,
                           reprocess_switch=reprocess_switch,
                           process_PTs=process_PTs,
                           process_airborne=process_airborne,
                           dist_thresh_offset=dist_thresh_offset,
                           time_thresh_offset=time_thresh_offset,
                           GNSS_sd_thresh=GNSS_sd_thresh,
                           offset_sd_thresh=offset_sd_thresh,
                           change_thresh_15_min=change_thresh_15_min,
                           alongstream_error=alongstream_error,
                           crosstream_error=crosstream_error,
                           measurement_error=measurement_error, 
                            time_threshold_sec_match=time_threshold_sec_match,
                            wse_threshold_m_match=wse_threshold_m_match,
                            distance_threshold_m_match=distance_threshold_m_match)
# Out:
# [1] "/nas/cee-water/cjgleason/calval/cnes_watermasks/fromCNES_20230724/NS/extracteo/"
# [1] "filename SWOTCalVal_NS_GNSS_L2_Rec7_20230516T232900_20230517T001828_20230530T162530 bonked"
# [1] "Munged drifts/reprocessed_2023_08_22/SWOTCalVal_NS_GNSS_L2_Rec7_20230523T153700_20230523T224005_20230530T164153_1.csv"
# [1] "Munged drifts/reprocessed_2023_08_22/SWOTCalVal_NS_GNSS_L2_Rec7_20230523T153700_20230523T224005_20230530T164153_2.csv"
# [1] "Munged drifts/reprocessed_2023_08_22/SWOTCalVal_NS_GNSS_L2_Rec7_20230525T125517_20230525T235848_20230530T172736_1.csv"
# [1] "Munged drifts/reprocessed_2023_08_22/SWOTCalVal_NS_GNSS_L2_Rec7_20230525T125517_20230525T235848_20230530T172736_2.csv"
# [1] "Munged drifts/reprocessed_2023_08_22/SWOTCalVal_NS_GNSS_L2_Rec7_20230526T131339_20230526T215514_20230530T184655_1.csv"
# [1] "Munged drifts/reprocessed_2023_08_22/SWOTCalVal_NS_GNSS_L2_Rec7_20230526T131339_20230526T215514_20230530T184655_2.csv"
# [1] "Munged drifts/reprocessed_2023_08_22/SWOTCalVal_NS_GNSS_L2_Rec7_20
of `y` matches multiple rows in `x`.
# ℹ If a many-to-many relationship is expected, set `relationship =
#   "many-to-many"` to silence this warning.”
# `summarise()` has grouped output by 'node_id'. You can override using the
# `.groups` argument.
# Warning message in left_join(., key_df, by = "pt_serial"):
# “Detected an unexpected many-to-many relationship between `x` and `y`.
# ℹ Row 723 of `x` matches multiple rows in `y`.
# ℹ Row 8 of `y` matches multiple rows in `x`.
# ℹ If a many-to-many relationship is expected, set `relationship =
#   "many-to-many"` to silence this warning.”
# `summarise()` has grouped output by 'node_id'. You can override using the
# `.groups` argument.
# Warning message in left_join(., key_df, by = "pt_serial"):
# “Detected an unexpected many-to-many relationship between `x` and `y`.
# ℹ Row 723 of `x` matches multiple rows in `y`.
# ℹ Row 8 of `y` matches multiple rows in `x`.
# ℹ If a many-to-many relationship is expected, set `relationship =
#   "many-to-many"` to silence this warning.”
# `summarise()` has grouped output by 'node_id'. You can override using the
# `.groups` argument.
# Warning message in left_join(., key_df, by = "pt_serial"):
# “Detected an unexpected many-to-many relationship between `x` and `y`.
# ℹ Row 723 of `x` matches multiple rows in `y`.
# ℹ Row 8 of `y` matches multiple rows in `x`.
# ℹ If a many-to-many relationship is expected, set `relationship =
#   "many-to-many"` to silence this warning.”
# `summarise()` has grouped output by 'node_id'. You can override using the
# `.groups` argument.
# Warning message in left_join(., key_df, by = "pt_serial"):
# “Detected an unexpected many-to-many relationship between `x` and `y`.
# ℹ Row 723 of `x` matches multiple rows in `y`.
# ℹ Row 8 of `y` matches multiple rows in `x`.
# ℹ If a many-to-many relationship is expected, set `relationship =
#   "many-to-many"` to silence this warning.”
# `summarise()` has grouped output by 'node_id'. You can override using the
# `.groups` argument.
# Warning message in left_join(., key_df, by = "pt_serial"):
# “Detected an unexpected many-to-many relationship between `x` and `y`.
# ℹ Row 723 of `x` matches multiple rows in `y`.
# ℹ Row 8 of `y` matches multiple rows in `x`.
# ℹ If a many-to-many relationship is expected, set `relationship =
#   "many-to-many"` to silence this warning.”
# `summarise()` has grouped output by 'node_id'. You can override using the
# `.groups` argument.
# Warning message in left_join(., key_df, by = "pt_serial"):
# “Detected an unexpected many-to-many relationship between `x` and `y`.
# ℹ Row 723 of `x` matches multiple rows in `y`.
# ℹ Row 8 of `y` matches multiple rows in `x`.
# ℹ If a many-to-many relationship is expected, set `relationship =
#   "many-to-many"` to silence this warning.”
# `summarise()` has grouped output by 'node_id'. You can override using the
# `.groups` argument.
# Warning message in left_join(., key_df, by = "pt_serial"):
# “Detected an unexpected many-to-many relationship between `x` and `y`.
# ℹ Row 723 of `x` matches multiple rows in `y`.
# ℹ Row 8 of `y` matches multiple rows in `x`.
# ℹ If a many-to-many relationship is expected, set `relationship =
#   "many-to-many"` to silence this warning.”
# `summarise()` has grouped output by 'node_id'. You can override using the
# `.groups` argument.
# Warning message in left_join(., key_df, by = "pt_serial"):
# “Detected an unexpected many-to-many relationship between `x` and `y`.
# ℹ Row 723 of `x` matches multiple rows in `y`.
# ℹ Row 8 of `y` matches multiple rows in `x`.
# ℹ If a many-to-many relationship is expected, set `relationship =
#   "many-to-many"` to silence this warning.”
# `summarise()` has grouped output by 'node_id'. You can override using the
# `.groups` argument.
# Warning message in left_join(., key_df, by = "pt_serial"):
# “Detected an unexpected many-to-many relationship between `x` and `y`.
# ℹ Row 723 of `x` matches multiple rows in `y`.
# ℹ Row 8 of `y` matches multiple rows in `x`.
# ℹ If a many-to-many relationship is expected, set `relationship =
#   "many-to-many"` to silence this warning.”
# `summarise()` has grouped output by 'node_id'. You can override using the
# `.groups` argument.
# Warning message in left_join(., key_df, by = "pt_serial"):
# “Detected an unexpected many-to-many relationship between `x` and `y`.
# ℹ Row 723 of `x` matches multiple rows in `y`.
# ℹ Row 8 of `y` matches multiple rows in `x`.
# ℹ If a many-to-many relationship is expected, set `relationship =
#   "many-to-many"` to silence this warning.”
# `summarise()` has grouped output by 'node_id'. You can override using the
# `.groups` argument.
# Warning message in left_join(., key_df, by = "pt_serial"):
# “Detected an unexpected many-to-many relationship between `x` and `y`.
# ℹ Row 723 of `x` matches multiple rows in `y`.
# ℹ Row 8 of `y` matches multiple rows in `x`.
# ℹ If a many-to-many relationship is expected, set `relationship =
#   "many-to-many"` to silence this warning.”
# `summarise()` has grouped output by 'node_id'. You can override using the
# `.groups` argument.
# Warning message in left_join(., key_df, by = "pt_serial"):
# “Detected an unexpected many-to-many relationship between `x` and `y`.
# ℹ Row 723 of `x` matches multiple rows in `y`.
# ℹ Row 8 of `y` matches multiple rows in `x`.
# ℹ If a many-to-many relationship is expected, set `relationship =
#   "many-to-many"` to silence this warning.”
# `summarise()` has grouped output by 'node_id'. You can override using the
# `.groups` argument.
# Warning message in left_join(., key_df, by = "pt_serial"):
# “Detected an unexpected many-to-many relationship between `x` and `y`.
# ℹ Row 723 of `x` matches multiple rows in `y`.
# ℹ Row 8 of `y` matches multiple rows in `x`.
# ℹ If a many-to-many relationship is expected, set `relationship =
#   "many-to-many"` to silence this warning.”
# `summarise()` has grouped output by 'node_id'. You can override using the
# `.groups` argument.
# Warning message in left_join(., key_df, by = "pt_serial"):
# “Detected an unexpected many-to-many relationship between `x` and `y`.
# ℹ Row 723 of `x` matches multiple rows in `y`.
# ℹ Row 8 of `y` matches multiple rows in `x`.
# ℹ If a many-to-many relationship is expected, set `relationship =
#   "many-to-many"` to silence this warning.”
# `summarise()` has grouped output by 'node_id'. You can override using the
# `.groups` argument.
# Warning message in left_join(., key_df, by = "pt_serial"):
# “Detected an unexpected many-to-many relationship between `x` and `y`.
# ℹ Row 723 of `x` matches multiple rows in `y`.
# ℹ Row 8 of `y` matches multiple rows in `x`.
# ℹ If a many-to-many relationship is expected, set `relationship =
#   "many-to-many"` to silence this warning.”
# `summarise()` has grouped output by 'node_id'. You can override using the
# `.groups` argument.
# Warning message in left_join(., key_df, by = "pt_serial"):
# “Detected an unexpected many-to-many relationship between `x` and `y`.
# ℹ Row 723 of `x` matches multiple rows in `y`.
# ℹ Row 8 of `y` matches multiple rows in `x`.
# ℹ If a many-to-many relationship is expected, set `relationship =
#   "many-to-many"` to silence this warning.”
# `summarise()` has grouped output by 'node_id'. You can override using the
# `.groups` argument.
# Warning message in left_join(., key_df, by = "pt_serial"):
# “Detected an unexpected many-to-many relationship between `x` and `y`.
# ℹ Row 723 of `x` matches multiple rows in `y`.
# ℹ Row 8 of `y` matches multiple rows in `x`.
# ℹ If a many-to-many relationship is expected, set `relationship =
#   "many-to-many"` to silence this warning.”
# `summarise()` has grouped output by 'node_id'. You can override using the
# `.groups` argument.
# Warning message in left_join(., key_df, by = "pt_serial"):
# “Detected an unexpected many-to-many relationship between `x` and `y`.
# ℹ Row 723 of `x` matches multiple rows in `y`.
# ℹ Row 8 of `y` matches multiple rows in `x`.
# ℹ If a many-to-many relationship is expected, set `relationship =
#   "many-to-many"` to silence this warning.”
# `summarise()` has grouped output by 'node_id'. You can override using the
# `.groups` argument.
